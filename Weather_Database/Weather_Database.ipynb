# %%
# Import the dependencies.
import pandas as pd
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 787

# %%
# Create an empty list to hold the weather data.
city_data = []
# Loop through all the cities in the list.
record_count = 1
set_count = 1

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_current_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Out:
# Processing Record 1 of Set 1 | ahipara
# Processing Record 2 of Set 1 | tasiilaq
# Processing Record 3 of Set 1 | muros
# Processing Record 4 of Set 1 | gat
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | bubaque
# Processing Record 7 of Set 1 | borba
# Processing Record 8 of Set 1 | kuroiso
# Processing Record 9 of Set 1 | jamestown
# Processing Record 10 of Set 1 | hithadhoo
# Processing Record 11 of Set 1 | karpathos
# Processing Record 12 of Set 1 | east london
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | coihaique
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | yellowknife
# Processing Record 18 of Set 1 | kapaa
# Processing Record 19 of Set 1 | mount pleasant
# Processing Record 20 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 1 | alexandria
# Processing Record 22 of Set 1 | flin flon
# Processing Record 23 of Set 1 | albany
# Processing Record 24 of Set 1 | moose factory
# Processing Record 25 of Set 1 | lazaro cardenas
# Processing Record 26 of Set 1 | mahebourg
# Processing Record 27 of Set 1 | havelock
# Processing Record 28 of Set 1 | puerto ayora
# Processing Record 29 of Set 1 | puerto baquerizo moreno
# Processing Record 30 of Set 1 | punta arenas
# Processing Record 31 of Set 1 | ambilobe
# Processing Record 32 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 1 | villarrica
# Processing Record 34 of Set 1 | vila
# Processing Record 35 of Set 1 | pevek
# Processing Record 36 of Set 1 | mar del plata
# Processing Record 37 of Set 1 | kodiak
# Processing Record 38 of Set 1 | kota belud
# Processing Record 39 of Set 1 | vestmannaeyjar
# Processing Record 40 of Set 1 | lanja
# Processing Record 41 of Set 1 | nikolskoye
# Processing Record 42 of Set 1 | atuona
# Processing Record 43 of Set 1 | trairi
# Processing Record 44 of Set 1 | at-bashi
# Processing Record 45 of Set 1 | port alfred
# Processing Record 46 of Set 1 | ondjiva
# Processing Record 47 of Set 1 | vallenar
# Processing Record 48 of Set 1 | borkenes
# Processing Record 49 of Set 1 | stepnogorsk
# Processing Record 50 of Set 1 | kamaishi
# Processing Record 1 of Set 2 | kabare
# Processing Record 2 of Set 2 | hermanus
# Processing Record 3 of Set 2 | axim
# Processing Record 4 of Set 2 | cap malheureux
# Processing Record 5 of Set 2 | la asuncion
# Processing Record 6 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 2 | iqaluit
# Processing Record 8 of Set 2 | rodrigues alves
# Processing Record 9 of Set 2 | walvis bay
# Processing Record 10 of Set 2 | kharan
# Processing Record 11 of Set 2 | dikson
# Processing Record 12 of Set 2 | butaritari
# Processing Record 13 of Set 2 | qom
# Processing Record 14 of Set 2 | heyang
# Processing Record 15 of Set 2 | dudinka
# Processing Record 16 of Set 2 | port elizabeth
# Processing Record 17 of Set 2 | redmond
# Processing Record 18 of Set 2 | coahuayana
# Processing Record 19 of Set 2 | birin
# Processing Record 20 of Set 2 | mwinilunga
# Processing Record 21 of Set 2 | khatanga
# Processing Record 22 of Set 2 | new norfolk
# Processing Record 23 of Set 2 | waingapu
# Processing Record 24 of Set 2 | airai
# Processing Record 25 of Set 2 | iralaya
# Processing Record 26 of Set 2 | amapa
# Processing Record 27 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 2 | hobart
# Processing Record 30 of Set 2 | srednekolymsk
# Processing Record 31 of Set 2 | severo-kurilsk
# Processing Record 32 of Set 2 | omutinskoye
# City not found. Skipping...
# Processing Record 33 of Set 2 | peniche
# Processing Record 34 of Set 2 | ancud
# Processing Record 35 of Set 2 | lorengau
# Processing Record 36 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 2 | rocha
# Processing Record 38 of Set 2 | chokurdakh
# Processing Record 39 of Set 2 | port-cartier
# Processing Record 40 of Set 2 | parauna
# Processing Record 41 of Set 2 | san patricio
# Processing Record 42 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 43 of Set 2 | frunze
# Processing Record 44 of Set 2 | bud
# Processing Record 45 of Set 2 | red wing
# Processing Record 46 of Set 2 | simbahan
# Processing Record 47 of Set 2 | krasnoselkup
# Processing Record 48 of Set 2 | tuktoyaktuk
# Processing Record 49 of Set 2 | victoria
# Processing Record 50 of Set 2 | benghazi
# Processing Record 1 of Set 3 | mansa
# Processing Record 2 of Set 3 | atar
# Processing Record 3 of Set 3 | zihuatanejo
# Processing Record 4 of Set 3 | padang
# Processing Record 5 of Set 3 | egvekinot
# Processing Record 6 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 3 | mayo
# Processing Record 8 of Set 3 | faanui
# Processing Record 9 of Set 3 | saint-pierre
# Processing Record 10 of Set 3 | georgetown
# Processing Record 11 of Set 3 | gravdal
# Processing Record 12 of Set 3 | bredasdorp
# Processing Record 13 of Set 3 | tiksi
# Processing Record 14 of Set 3 | nakamura
# Processing Record 15 of Set 3 | carnarvon
# Processing Record 16 of Set 3 | saskylakh
# Processing Record 17 of Set 3 | inhambane
# Processing Record 18 of Set 3 | katsuura
# Processing Record 19 of Set 3 | chimore
# Processing Record 20 of Set 3 | enshi
# Processing Record 21 of Set 3 | kedrovyy
# Processing Record 22 of Set 3 | bluff
# Processing Record 23 of Set 3 | marsa matruh
# Processing Record 24 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 3 | kahului
# Processing Record 26 of Set 3 | cape town
# Processing Record 27 of Set 3 | pokhara
# Processing Record 28 of Set 3 | tazovskiy
# Processing Record 29 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 30 of Set 3 | ukiah
# Processing Record 31 of Set 3 | mpanda
# Processing Record 32 of Set 3 | broome
# Processing Record 33 of Set 3 | coquimbo
# Processing Record 34 of Set 3 | rapar
# Processing Record 35 of Set 3 | longyearbyen
# Processing Record 36 of Set 3 | cherskiy
# Processing Record 37 of Set 3 | wulanhaote
# City not found. Skipping...
# Processing Record 38 of Set 3 | valuyki
# Processing Record 39 of Set 3 | kanker
# Processing Record 40 of Set 3 | kieta
# Processing Record 41 of Set 3 | arraial do cabo
# Processing Record 42 of Set 3 | ribeira grande
# Processing Record 43 of Set 3 | gucheng
# Processing Record 44 of Set 3 | qaanaaq
# Processing Record 45 of Set 3 | vila velha
# Processing Record 46 of Set 3 | tilichiki
# Processing Record 47 of Set 3 | norman wells
# Processing Record 48 of Set 3 | kanata
# Processing Record 49 of Set 3 | vaini
# Processing Record 50 of Set 3 | seoul
# Processing Record 1 of Set 4 | klaksvik
# Processing Record 2 of Set 4 | robertsport
# Processing Record 3 of Set 4 | eseka
# Processing Record 4 of Set 4 | farafangana
# Processing Record 5 of Set 4 | paradwip
# City not found. Skipping...
# Processing Record 6 of Set 4 | saldanha
# Processing Record 7 of Set 4 | palestina
# Processing Record 8 of Set 4 | keetmanshoop
# Processing Record 9 of Set 4 | tautira
# Processing Record 10 of Set 4 | lamu
# Processing Record 11 of Set 4 | avarua
# Processing Record 12 of Set 4 | waipawa
# Processing Record 13 of Set 4 | nizhniy tsasuchey
# Processing Record 14 of Set 4 | manta
# Processing Record 15 of Set 4 | danville
# Processing Record 16 of Set 4 | lebu
# Processing Record 17 of Set 4 | oktyabrskiy
# Processing Record 18 of Set 4 | carutapera
# Processing Record 19 of Set 4 | tuatapere
# Processing Record 20 of Set 4 | sumbawanga
# Processing Record 21 of Set 4 | safwah
# City not found. Skipping...
# Processing Record 22 of Set 4 | salinas
# Processing Record 23 of Set 4 | provideniya
# Processing Record 24 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 25 of Set 4 | barrow
# Processing Record 26 of Set 4 | talnakh
# Processing Record 27 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 28 of Set 4 | banjarmasin
# Processing Record 29 of Set 4 | los llanos de aridane
# Processing Record 30 of Set 4 | labuan
# Processing Record 31 of Set 4 | tunduma
# Processing Record 32 of Set 4 | port hedland
# Processing Record 33 of Set 4 | bedele
# Processing Record 34 of Set 4 | grindavik
# Processing Record 35 of Set 4 | lompoc
# Processing Record 36 of Set 4 | hovd
# Processing Record 37 of Set 4 | orlik
# Processing Record 38 of Set 4 | challapata
# Processing Record 39 of Set 4 | taltal
# Processing Record 40 of Set 4 | sorong
# Processing Record 41 of Set 4 | half moon bay
# Processing Record 42 of Set 4 | guerrero negro
# Processing Record 43 of Set 4 | zonguldak
# Processing Record 44 of Set 4 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 45 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 4 | mentok
# City not found. Skipping...
# Processing Record 47 of Set 4 | cabo san lucas
# Processing Record 48 of Set 4 | porangatu
# Processing Record 49 of Set 4 | icod de los vinos
# Processing Record 50 of Set 4 | sangar
# Processing Record 1 of Set 5 | ouegoa
# Processing Record 2 of Set 5 | san cristobal
# Processing Record 3 of Set 5 | pitrufquen
# Processing Record 4 of Set 5 | gizo
# Processing Record 5 of Set 5 | bolanos de calatrava
# Processing Record 6 of Set 5 | nautla
# Processing Record 7 of Set 5 | jiexiu
# Processing Record 8 of Set 5 | acapulco
# Processing Record 9 of Set 5 | pathein
# Processing Record 10 of Set 5 | caohe
# Processing Record 11 of Set 5 | soyo
# Processing Record 12 of Set 5 | asau
# Processing Record 13 of Set 5 | tomatlan
# Processing Record 14 of Set 5 | akureyri
# Processing Record 15 of Set 5 | ulladulla
# Processing Record 16 of Set 5 | goksun
# Processing Record 17 of Set 5 | qandala
# Processing Record 18 of Set 5 | buta
# Processing Record 19 of Set 5 | vilhena
# Processing Record 20 of Set 5 | luneville
# Processing Record 21 of Set 5 | beringovskiy
# Processing Record 22 of Set 5 | maputo
# Processing Record 23 of Set 5 | aguada de pasajeros
# Processing Record 24 of Set 5 | saint george
# Processing Record 25 of Set 5 | gilgit
# Processing Record 26 of Set 5 | aklavik
# Processing Record 27 of Set 5 | yulara
# Processing Record 28 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 5 | sokoni
# Processing Record 30 of Set 5 | keningau
# Processing Record 31 of Set 5 | olinda
# Processing Record 32 of Set 5 | daru
# Processing Record 33 of Set 5 | bilma
# Processing Record 34 of Set 5 | clyde river
# Processing Record 35 of Set 5 | aksu
# Processing Record 36 of Set 5 | bairiki
# Processing Record 37 of Set 5 | polis
# Processing Record 38 of Set 5 | burnie
# Processing Record 39 of Set 5 | picos
# Processing Record 40 of Set 5 | nioki
# Processing Record 41 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 42 of Set 5 | vredendal
# Processing Record 43 of Set 5 | les cayes
# Processing Record 44 of Set 5 | minudasht
# Processing Record 45 of Set 5 | fort saint james
# Processing Record 46 of Set 5 | maralal
# Processing Record 47 of Set 5 | abhar
# Processing Record 48 of Set 5 | oksfjord
# Processing Record 49 of Set 5 | lavrentiya
# Processing Record 50 of Set 5 | necochea
# Processing Record 1 of Set 6 | palmer
# Processing Record 2 of Set 6 | loandjili
# Processing Record 3 of Set 6 | bambanglipuro
# Processing Record 4 of Set 6 | crab hill
# City not found. Skipping...
# Processing Record 5 of Set 6 | nchelenge
# Processing Record 6 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 6 | flinders
# Processing Record 8 of Set 6 | baracoa
# Processing Record 9 of Set 6 | leh
# Processing Record 10 of Set 6 | deputatskiy
# Processing Record 11 of Set 6 | ilulissat
# Processing Record 12 of Set 6 | mitsamiouli
# Processing Record 13 of Set 6 | razole
# Processing Record 14 of Set 6 | huetamo
# City not found. Skipping...
# Processing Record 15 of Set 6 | chuy
# Processing Record 16 of Set 6 | riachao das neves
# Processing Record 17 of Set 6 | youkounkoun
# Processing Record 18 of Set 6 | abatskoye
# Processing Record 19 of Set 6 | sao filipe
# Processing Record 20 of Set 6 | ban phai
# Processing Record 21 of Set 6 | sitka
# Processing Record 22 of Set 6 | bengkulu
# Processing Record 23 of Set 6 | nanortalik
# Processing Record 24 of Set 6 | liverpool
# Processing Record 25 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 6 | luderitz
# Processing Record 27 of Set 6 | hobyo
# Processing Record 28 of Set 6 | cidreira
# Processing Record 29 of Set 6 | luwuk
# Processing Record 30 of Set 6 | lagoa
# Processing Record 31 of Set 6 | the valley
# Processing Record 32 of Set 6 | santa maria
# Processing Record 33 of Set 6 | labuhan
# Processing Record 34 of Set 6 | praia
# Processing Record 35 of Set 6 | saint-philippe
# Processing Record 36 of Set 6 | leningradskiy
# Processing Record 37 of Set 6 | mantua
# Processing Record 38 of Set 6 | tual
# Processing Record 39 of Set 6 | odweyne
# Processing Record 40 of Set 6 | anadyr
# Processing Record 41 of Set 6 | port-gentil
# Processing Record 42 of Set 6 | mehamn
# Processing Record 43 of Set 6 | sinjar
# Processing Record 44 of Set 6 | castro
# Processing Record 45 of Set 6 | olafsvik
# Processing Record 46 of Set 6 | thompson
# Processing Record 47 of Set 6 | ponta do sol
# Processing Record 48 of Set 6 | geraldton
# Processing Record 49 of Set 6 | chandla
# Processing Record 50 of Set 6 | salekhard
# Processing Record 1 of Set 7 | hervey bay
# Processing Record 2 of Set 7 | upernavik
# Processing Record 3 of Set 7 | puli
# Processing Record 4 of Set 7 | saint-joseph
# Processing Record 5 of Set 7 | harper
# Processing Record 6 of Set 7 | iringa
# Processing Record 7 of Set 7 | safranbolu
# Processing Record 8 of Set 7 | hilo
# Processing Record 9 of Set 7 | brigantine
# Processing Record 10 of Set 7 | stutterheim
# Processing Record 11 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 7 | lahij
# Processing Record 13 of Set 7 | sao joao da barra
# Processing Record 14 of Set 7 | alyangula
# Processing Record 15 of Set 7 | nisia floresta
# Processing Record 16 of Set 7 | ulverstone
# Processing Record 17 of Set 7 | tortoli
# Processing Record 18 of Set 7 | ostroh
# Processing Record 19 of Set 7 | elk city
# Processing Record 20 of Set 7 | kholm-zhirkovskiy
# Processing Record 21 of Set 7 | bethel
# Processing Record 22 of Set 7 | norden
# Processing Record 23 of Set 7 | kruisfontein
# Processing Record 24 of Set 7 | codrington
# Processing Record 25 of Set 7 | mananjary
# Processing Record 26 of Set 7 | fortuna
# Processing Record 27 of Set 7 | west wendover
# Processing Record 28 of Set 7 | lisala
# Processing Record 29 of Set 7 | staryy nadym
# Processing Record 30 of Set 7 | althofen
# Processing Record 31 of Set 7 | lulea
# Processing Record 32 of Set 7 | goundi
# Processing Record 33 of Set 7 | mangrol
# Processing Record 34 of Set 7 | naryan-mar
# Processing Record 35 of Set 7 | roma
# Processing Record 36 of Set 7 | bojaya
# City not found. Skipping...
# Processing Record 37 of Set 7 | virginia beach
# Processing Record 38 of Set 7 | tibagi
# Processing Record 39 of Set 7 | luchegorsk
# Processing Record 40 of Set 7 | sao felix do xingu
# Processing Record 41 of Set 7 | esperance
# Processing Record 42 of Set 7 | eyl
# Processing Record 43 of Set 7 | whitianga
# Processing Record 44 of Set 7 | galeana
# Processing Record 45 of Set 7 | swan hill
# Processing Record 46 of Set 7 | kaitangata
# Processing Record 47 of Set 7 | lodja
# Processing Record 48 of Set 7 | nome
# Processing Record 49 of Set 7 | kongoussi
# Processing Record 50 of Set 7 | ambositra
# Processing Record 1 of Set 8 | okhotsk
# Processing Record 2 of Set 8 | sapao
# City not found. Skipping...
# Processing Record 3 of Set 8 | ordu
# Processing Record 4 of Set 8 | mogadishu
# Processing Record 5 of Set 8 | labytnangi
# Processing Record 6 of Set 8 | kaihua
# Processing Record 7 of Set 8 | villa carlos paz
# Processing Record 8 of Set 8 | ilo
# Processing Record 9 of Set 8 | manaure
# Processing Record 10 of Set 8 | beyneu
# Processing Record 11 of Set 8 | honiara
# Processing Record 12 of Set 8 | kirakira
# Processing Record 13 of Set 8 | santa isabel do rio negro
# Processing Record 14 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 8 | vila franca do campo
# Processing Record 16 of Set 8 | nioro
# Processing Record 17 of Set 8 | barcelos
# Processing Record 18 of Set 8 | katha
# City not found. Skipping...
# Processing Record 19 of Set 8 | fez
# Processing Record 20 of Set 8 | nouadhibou
# Processing Record 21 of Set 8 | la ronge
# Processing Record 22 of Set 8 | gazanjyk
# Processing Record 23 of Set 8 | kattivakkam
# Processing Record 24 of Set 8 | poum
# Processing Record 25 of Set 8 | sinnamary
# Processing Record 26 of Set 8 | camacha
# Processing Record 27 of Set 8 | rancho palos verdes
# Processing Record 28 of Set 8 | zholymbet
# Processing Record 29 of Set 8 | natchez
# Processing Record 30 of Set 8 | kokopo
# Processing Record 31 of Set 8 | trincomalee
# Processing Record 32 of Set 8 | sao gabriel da cachoeira
# Processing Record 33 of Set 8 | asekeyevo
# Processing Record 34 of Set 8 | rochegda
# Processing Record 35 of Set 8 | stokmarknes
# Processing Record 36 of Set 8 | valparaiso
# Processing Record 37 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 38 of Set 8 | manokwari
# Processing Record 39 of Set 8 | butajira
# Processing Record 40 of Set 8 | port hardy
# Processing Record 41 of Set 8 | najran
# Processing Record 42 of Set 8 | maarianhamina
# Processing Record 43 of Set 8 | port blair
# Processing Record 44 of Set 8 | sidi bu zayd
# City not found. Skipping...
# Processing Record 45 of Set 8 | santa rosa
# Processing Record 46 of Set 8 | stornoway
# Processing Record 47 of Set 8 | ust-ilimsk
# Processing Record 48 of Set 8 | fort nelson
# Processing Record 49 of Set 8 | hualmay
# Processing Record 50 of Set 8 | mutsamudu
# City not found. Skipping...
# Processing Record 1 of Set 9 | souillac
# Processing Record 2 of Set 9 | luba
# Processing Record 3 of Set 9 | prince rupert
# Processing Record 4 of Set 9 | kamenka
# Processing Record 5 of Set 9 | boa vista
# Processing Record 6 of Set 9 | florianopolis
# Processing Record 7 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 8 of Set 9 | beni
# Processing Record 9 of Set 9 | kaeo
# Processing Record 10 of Set 9 | oranjestad
# Processing Record 11 of Set 9 | pierre
# Processing Record 12 of Set 9 | amazar
# Processing Record 13 of Set 9 | sterling
# Processing Record 14 of Set 9 | rio gallegos
# Processing Record 15 of Set 9 | albertville
# Processing Record 16 of Set 9 | narsaq
# Processing Record 17 of Set 9 | pisco
# Processing Record 18 of Set 9 | suamico
# Processing Record 19 of Set 9 | kartaly
# Processing Record 20 of Set 9 | copiapo
# Processing Record 21 of Set 9 | pangnirtung
# Processing Record 22 of Set 9 | wagar
# Processing Record 23 of Set 9 | yining
# Processing Record 24 of Set 9 | blackwater
# Processing Record 25 of Set 9 | abu samrah
# Processing Record 26 of Set 9 | nagutskoye
# Processing Record 27 of Set 9 | mankono
# Processing Record 28 of Set 9 | douglas
# Processing Record 29 of Set 9 | miami
# Processing Record 30 of Set 9 | yarmouth
# Processing Record 31 of Set 9 | mao
# Processing Record 32 of Set 9 | phan thiet
# Processing Record 33 of Set 9 | state college
# Processing Record 34 of Set 9 | bredy
# Processing Record 35 of Set 9 | mbaiki
# Processing Record 36 of Set 9 | zacualtipan
# Processing Record 37 of Set 9 | derzhavinsk
# Processing Record 38 of Set 9 | dicabisagan
# Processing Record 39 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 40 of Set 9 | auch
# Processing Record 41 of Set 9 | jimeta
# Processing Record 42 of Set 9 | dinahican
# Processing Record 43 of Set 9 | panaba
# Processing Record 44 of Set 9 | mount isa
# Processing Record 45 of Set 9 | mackay
# Processing Record 46 of Set 9 | pavino
# Processing Record 47 of Set 9 | sibolga
# Processing Record 48 of Set 9 | dandong
# Processing Record 49 of Set 9 | antalaha
# Processing Record 50 of Set 9 | sortland
# Processing Record 1 of Set 10 | boyuibe
# Processing Record 2 of Set 10 | shingu
# Processing Record 3 of Set 10 | puerto escondido
# Processing Record 4 of Set 10 | dahegam
# Processing Record 5 of Set 10 | brownsville
# Processing Record 6 of Set 10 | tabou
# Processing Record 7 of Set 10 | iquique
# Processing Record 8 of Set 10 | kostomuksha
# Processing Record 9 of Set 10 | benguela
# Processing Record 10 of Set 10 | lodwar
# Processing Record 11 of Set 10 | vao
# Processing Record 12 of Set 10 | ugoofaaru
# Processing Record 13 of Set 10 | el mahalla el kubra
# City not found. Skipping...
# Processing Record 14 of Set 10 | lushunkou
# City not found. Skipping...
# Processing Record 15 of Set 10 | saint-augustin
# Processing Record 16 of Set 10 | mattru
# Processing Record 17 of Set 10 | wahpeton
# Processing Record 18 of Set 10 | prado
# Processing Record 19 of Set 10 | dongsheng
# Processing Record 20 of Set 10 | mareeba
# Processing Record 21 of Set 10 | oranjemund
# Processing Record 22 of Set 10 | avera
# Processing Record 23 of Set 10 | saryshagan
# City not found. Skipping...
# Processing Record 24 of Set 10 | debre birhan
# Processing Record 25 of Set 10 | kuytun
# Processing Record 26 of Set 10 | sheridan
# Processing Record 27 of Set 10 | port macquarie
# Processing Record 28 of Set 10 | pacific grove
# Processing Record 29 of Set 10 | zemio
# Processing Record 30 of Set 10 | portland
# Processing Record 31 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 32 of Set 10 | teguldet
# Processing Record 33 of Set 10 | sur
# Processing Record 34 of Set 10 | asfi
# Processing Record 35 of Set 10 | chitral
# Processing Record 36 of Set 10 | yirol
# City not found. Skipping...
# Processing Record 37 of Set 10 | hamilton
# Processing Record 38 of Set 10 | te anau
# Processing Record 39 of Set 10 | pangai
# Processing Record 40 of Set 10 | mnogovershinnyy
# Processing Record 41 of Set 10 | dingle
# Processing Record 42 of Set 10 | mandalgovi
# Processing Record 43 of Set 10 | marzuq
# Processing Record 44 of Set 10 | vidim
# Processing Record 45 of Set 10 | byron bay
# Processing Record 46 of Set 10 | torbay
# Processing Record 47 of Set 10 | aswan
# Processing Record 48 of Set 10 | beni suef
# Processing Record 49 of Set 10 | shache
# Processing Record 50 of Set 10 | konstantinovka
# Processing Record 1 of Set 11 | berlevag
# Processing Record 2 of Set 11 | ouango
# Processing Record 3 of Set 11 | dhidhdhoo
# Processing Record 4 of Set 11 | glencoe
# Processing Record 5 of Set 11 | fairbanks
# Processing Record 6 of Set 11 | puerto colombia
# Processing Record 7 of Set 11 | mumford
# Processing Record 8 of Set 11 | kijang
# Processing Record 9 of Set 11 | along
# Processing Record 10 of Set 11 | wuning
# Processing Record 11 of Set 11 | the hague
# Processing Record 12 of Set 11 | lardos
# Processing Record 13 of Set 11 | bagdarin
# Processing Record 14 of Set 11 | nanchang
# Processing Record 15 of Set 11 | whitehaven
# Processing Record 16 of Set 11 | santa vitoria
# Processing Record 17 of Set 11 | yuancheng
# Processing Record 18 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 11 | bintulu
# Processing Record 20 of Set 11 | el paraiso
# Processing Record 21 of Set 11 | coyuca
# City not found. Skipping...
# Processing Record 22 of Set 11 | mecca
# Processing Record 23 of Set 11 | soldotna
# Processing Record 24 of Set 11 | touros
# Processing Record 25 of Set 11 | san jose
# Processing Record 26 of Set 11 | kavieng
# Processing Record 27 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 28 of Set 11 | ayan
# Processing Record 29 of Set 11 | jalu
# Processing Record 30 of Set 11 | aviles
# Processing Record 31 of Set 11 | basco
# Processing Record 32 of Set 11 | husavik
# Processing Record 33 of Set 11 | dunedin
# Processing Record 34 of Set 11 | jamame
# Processing Record 35 of Set 11 | elko
# Processing Record 36 of Set 11 | khalilabad
# Processing Record 37 of Set 11 | ust-nera
# Processing Record 38 of Set 11 | jumla
# Processing Record 39 of Set 11 | pasighat
# Processing Record 40 of Set 11 | lincoln
# Processing Record 41 of Set 11 | gamba
# Processing Record 42 of Set 11 | chicama
# Processing Record 43 of Set 11 | salalah
# Processing Record 44 of Set 11 | delray beach
# Processing Record 45 of Set 11 | podujevo
# Processing Record 46 of Set 11 | san andres
# Processing Record 47 of Set 11 | laguna
# Processing Record 48 of Set 11 | noumea
# Processing Record 49 of Set 11 | vardo
# Processing Record 50 of Set 11 | eagle pass
# Processing Record 1 of Set 12 | fremont
# Processing Record 2 of Set 12 | dwarka
# Processing Record 3 of Set 12 | rawson
# Processing Record 4 of Set 12 | ostrovnoy
# Processing Record 5 of Set 12 | maumere
# Processing Record 6 of Set 12 | comodoro rivadavia
# Processing Record 7 of Set 12 | sabzevar
# Processing Record 8 of Set 12 | yinchuan
# Processing Record 9 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 10 of Set 12 | yar-sale
# Processing Record 11 of Set 12 | praia da vitoria
# Processing Record 12 of Set 12 | baft
# Processing Record 13 of Set 12 | bealanana
# Processing Record 14 of Set 12 | kaili
# Processing Record 15 of Set 12 | phrai bung
# City not found. Skipping...
# Processing Record 16 of Set 12 | moron
# Processing Record 17 of Set 12 | bambari
# Processing Record 18 of Set 12 | kuusankoski
# Processing Record 19 of Set 12 | bambous virieux
# Processing Record 20 of Set 12 | san francisco
# Processing Record 21 of Set 12 | nemuro
# Processing Record 22 of Set 12 | midyat
# Processing Record 23 of Set 12 | marawi
# Processing Record 24 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 25 of Set 12 | namatanai
# Processing Record 26 of Set 12 | atbasar
# Processing Record 27 of Set 12 | saint-louis
# Processing Record 28 of Set 12 | verkhoshizhemye
# Processing Record 29 of Set 12 | northam
# Processing Record 30 of Set 12 | strezhevoy
# Processing Record 31 of Set 12 | lamont
# Processing Record 32 of Set 12 | inskoy
# Processing Record 33 of Set 12 | bereslavka
# Processing Record 34 of Set 12 | talcahuano
# Processing Record 35 of Set 12 | ceuta
# Processing Record 36 of Set 12 | camocim
# Processing Record 37 of Set 12 | nelson bay
# Processing Record 38 of Set 12 | tierra colorada
# Processing Record 39 of Set 12 | solnechnyy
# Processing Record 40 of Set 12 | san juan
# Processing Record 41 of Set 12 | tuscaloosa
# Processing Record 42 of Set 12 | lata
# Processing Record 43 of Set 12 | hohhot
# Processing Record 44 of Set 12 | karatuzskoye
# Processing Record 45 of Set 12 | lake forest
# Processing Record 46 of Set 12 | hay river
# Processing Record 47 of Set 12 | beian
# Processing Record 48 of Set 12 | athabasca
# Processing Record 49 of Set 12 | capitao poco
# Processing Record 50 of Set 12 | revelstoke
# Processing Record 1 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 2 of Set 13 | porto novo
# Processing Record 3 of Set 13 | berdigestyakh
# Processing Record 4 of Set 13 | chumikan
# Processing Record 5 of Set 13 | hinton
# Processing Record 6 of Set 13 | san quintin
# Processing Record 7 of Set 13 | henderson
# Processing Record 8 of Set 13 | olga
# Processing Record 9 of Set 13 | finschhafen
# Processing Record 10 of Set 13 | isangel
# Processing Record 11 of Set 13 | konosha
# Processing Record 12 of Set 13 | hambantota
# Processing Record 13 of Set 13 | samarai
# Processing Record 14 of Set 13 | rengo
# Processing Record 15 of Set 13 | yaan
# Processing Record 16 of Set 13 | helena
# Processing Record 17 of Set 13 | griffith
# Processing Record 18 of Set 13 | celestun
# Processing Record 19 of Set 13 | morales
# Processing Record 20 of Set 13 | pelotas
# Processing Record 21 of Set 13 | biak
# Processing Record 22 of Set 13 | matamoros
# Processing Record 23 of Set 13 | cayenne
# Processing Record 24 of Set 13 | hudson bay
# Processing Record 25 of Set 13 | west plains
# Processing Record 26 of Set 13 | namibe
# Processing Record 27 of Set 13 | petropavlovka
# Processing Record 28 of Set 13 | winona
# Processing Record 29 of Set 13 | scottsbluff
# Processing Record 30 of Set 13 | komsomolskiy
# Processing Record 31 of Set 13 | maposeni
# Processing Record 32 of Set 13 | kosa
# Processing Record 33 of Set 13 | parana
# Processing Record 34 of Set 13 | esna
# Processing Record 35 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 36 of Set 13 | alofi
# Processing Record 37 of Set 13 | rurrenabaque
# Processing Record 38 of Set 13 | estevan
# Processing Record 39 of Set 13 | nouakchott
# Processing Record 40 of Set 13 | emerald
# Processing Record 41 of Set 13 | narrabri
# Processing Record 42 of Set 13 | zacualpan
# Processing Record 43 of Set 13 | altar
# Processing Record 44 of Set 13 | preobrazheniye
# Processing Record 45 of Set 13 | iberia
# Processing Record 46 of Set 13 | erzin
# Processing Record 47 of Set 13 | kolokani
# Processing Record 48 of Set 13 | ruteng
# Processing Record 49 of Set 13 | laela
# Processing Record 50 of Set 13 | shimoda
# Processing Record 1 of Set 14 | trat
# Processing Record 2 of Set 14 | toktogul
# Processing Record 3 of Set 14 | sumbe
# Processing Record 4 of Set 14 | monroe
# Processing Record 5 of Set 14 | qui nhon
# Processing Record 6 of Set 14 | cockburn town
# Processing Record 7 of Set 14 | nokaneng
# Processing Record 8 of Set 14 | mananara
# Processing Record 9 of Set 14 | pakxe
# Processing Record 10 of Set 14 | tefe
# Processing Record 11 of Set 14 | paita
# Processing Record 12 of Set 14 | ketchikan
# Processing Record 13 of Set 14 | scarborough
# Processing Record 14 of Set 14 | bela
# Processing Record 15 of Set 14 | pailitas
# Processing Record 16 of Set 14 | soc trang
# Processing Record 17 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 18 of Set 14 | itoman
# Processing Record 19 of Set 14 | paamiut
# Processing Record 20 of Set 14 | porto velho
# Processing Record 21 of Set 14 | kapit
# Processing Record 22 of Set 14 | henties bay
# Processing Record 23 of Set 14 | gimli
# Processing Record 24 of Set 14 | lyubashivka
# Processing Record 25 of Set 14 | paranagua
# Processing Record 26 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 27 of Set 14 | gornyak
# Processing Record 28 of Set 14 | richards bay
# Processing Record 29 of Set 14 | myrtle beach
# Processing Record 30 of Set 14 | huilong
# Processing Record 31 of Set 14 | yerbogachen
# Processing Record 32 of Set 14 | antofagasta
# Processing Record 33 of Set 14 | urman
# Processing Record 34 of Set 14 | deep river
# Processing Record 35 of Set 14 | hasaki
# Processing Record 36 of Set 14 | vestbygda
# City not found. Skipping...
# Processing Record 37 of Set 14 | cabedelo
# Processing Record 38 of Set 14 | zhigansk
# Processing Record 39 of Set 14 | mocuba
# Processing Record 40 of Set 14 | salcedo
# Processing Record 41 of Set 14 | cocorit
# Processing Record 42 of Set 14 | garowe
# Processing Record 43 of Set 14 | kavaratti
# Processing Record 44 of Set 14 | naze
# Processing Record 45 of Set 14 | boshnyakovo
# Processing Record 46 of Set 14 | marquette
# Processing Record 47 of Set 14 | angoche
# Processing Record 48 of Set 14 | gornopravdinsk
# Processing Record 49 of Set 14 | upata
# Processing Record 50 of Set 14 | tezu
# Processing Record 1 of Set 15 | keti bandar
# Processing Record 2 of Set 15 | aguimes
# Processing Record 3 of Set 15 | tura
# Processing Record 4 of Set 15 | one hundred mile house
# City not found. Skipping...
# Processing Record 5 of Set 15 | rock island
# Processing Record 6 of Set 15 | drayton valley
# Processing Record 7 of Set 15 | viedma
# Processing Record 8 of Set 15 | la paz centro
# Processing Record 9 of Set 15 | mama
# Processing Record 10 of Set 15 | taft
# Processing Record 11 of Set 15 | armacao dos buzios
# City not found. Skipping...
# Processing Record 12 of Set 15 | asyut
# Processing Record 13 of Set 15 | miranda
# Processing Record 14 of Set 15 | neepawa
# Processing Record 15 of Set 15 | ulenje
# Processing Record 16 of Set 15 | cayambe
# Processing Record 17 of Set 15 | sandovo
# Processing Record 18 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 19 of Set 15 | quimper
# Processing Record 20 of Set 15 | kasongo-lunda
# Processing Record 21 of Set 15 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 22 of Set 15 | angra
# City not found. Skipping...
# Processing Record 23 of Set 15 | urusha
# Processing Record 24 of Set 15 | cedral
# Processing Record 25 of Set 15 | pishin
# Processing Record 26 of Set 15 | mazamet
# Processing Record 27 of Set 15 | muisne
# Processing Record 28 of Set 15 | malakal
# Processing Record 29 of Set 15 | makakilo city
# Processing Record 30 of Set 15 | grenada
# Processing Record 31 of Set 15 | high prairie
# Processing Record 32 of Set 15 | kasempa
# Processing Record 33 of Set 15 | atocha
# Processing Record 34 of Set 15 | severnyy-kospashskiy
# Processing Record 35 of Set 15 | sedelnikovo
# City not found. Skipping...
# Processing Record 36 of Set 15 | potosi
# Processing Record 37 of Set 15 | quatre cocos
# Processing Record 38 of Set 15 | sergeyevka
# Processing Record 39 of Set 15 | santa marta
# Processing Record 40 of Set 15 | thio
# Processing Record 41 of Set 15 | plettenberg bay
# Processing Record 42 of Set 15 | ambon
# Processing Record 43 of Set 15 | lastoursville
# Processing Record 44 of Set 15 | taree
# Processing Record 45 of Set 15 | halmaj
# Processing Record 46 of Set 15 | bumba
# Processing Record 47 of Set 15 | san vicente
# Processing Record 48 of Set 15 | sisimiut
# Processing Record 49 of Set 15 | elmont
# Processing Record 50 of Set 15 | manoel urbano
# Processing Record 1 of Set 16 | edzell
# Processing Record 2 of Set 16 | tombouctou
# Processing Record 3 of Set 16 | demyansk
# Processing Record 4 of Set 16 | majene
# Processing Record 5 of Set 16 | jvari
# Processing Record 6 of Set 16 | mocambique
# City not found. Skipping...
# Processing Record 7 of Set 16 | aguadilla
# Processing Record 8 of Set 16 | north bend
# Processing Record 9 of Set 16 | honningsvag
# Processing Record 10 of Set 16 | kuito
# Processing Record 11 of Set 16 | ialibu
# Processing Record 12 of Set 16 | rongcheng
# Processing Record 13 of Set 16 | klooga
# Processing Record 14 of Set 16 | novikovo
# Processing Record 15 of Set 16 | la malbaie
# Processing Record 16 of Set 16 | tapaua
# City not found. Skipping...
# Processing Record 17 of Set 16 | port-de-paix
# City not found. Skipping...
# Processing Record 18 of Set 16 | liuzhou
# Processing Record 19 of Set 16 | rioja
# Processing Record 20 of Set 16 | yatou
# Processing Record 21 of Set 16 | maldonado
# Processing Record 22 of Set 16 | lakhdenpokhya
# Processing Record 23 of Set 16 | novyye lyady
# Processing Record 24 of Set 16 | erzincan
# Processing Record 25 of Set 16 | takoradi
# Processing Record 26 of Set 16 | foz
# Processing Record 27 of Set 16 | ufa
# Processing Record 28 of Set 16 | chiang rai
# Processing Record 29 of Set 16 | kupang
# Processing Record 30 of Set 16 | nyurba
# Processing Record 31 of Set 16 | fuerte olimpo
# Processing Record 32 of Set 16 | mporokoso
# Processing Record 33 of Set 16 | faya
# Processing Record 34 of Set 16 | mayya
# Processing Record 35 of Set 16 | bull savanna
# Processing Record 36 of Set 16 | athens
# Processing Record 37 of Set 16 | kuyanovo

# %%
city_data
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df = city_data_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness","Wind Speed","Current Description"]]
city_data_df.head(10)
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Ahipara      NZ -35.1667  173.1667     61.77        85          26
# 1   Tasiilaq      GL  65.6145  -37.6368     32.16        88         100
# 2      Muros      ES  42.7762   -9.0603     61.84        89          31
# 3        Gat      IL  31.6100   34.7642     70.81       100           0
# 4    Rikitea      PF -23.1203 -134.9692     74.79        70          55
# 5    Bubaque      GW  11.2833  -15.8333     82.47        73         100
# 6      Borba      BR  -4.3878  -59.5939     91.36        52          71
# 7    Kuroiso      JP  36.9667  140.0500     45.82        76          42
# 8  Jamestown      US  42.0970  -79.2353     53.51        84          90
# 9  Hithadhoo      MV  -0.6000   73.0833     81.25        77          63
#
#    Wind Speed Current Description
# 0        2.59    scattered clouds
# 1       38.99                snow
# 2        2.26    scattered clouds
# 3        4.47           clear sky
# 4       16.04       broken clouds
# 5        6.31     overcast clouds
# 6        2.62       broken clouds
# 7        1.99    scattered clouds
# 8        4.00     overcast clouds
# 9       14.29       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
